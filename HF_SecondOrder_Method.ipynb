# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from __future__ import unicode_literals
# %matplotlib inline
params = {'legend.fontsize': 15, 'axes.labelsize': 15, 'xtick.labelsize': 15, 'ytick.labelsize': 15,
    'text.usetex': True, 'text.latex.unicode': True,
    'figure.figsize': (8, 8/1.6) }
plt.rcParams.update(params)
torch.set_default_dtype(torch.float64)

# %%
MAX = 1

def random(n, M = MAX):
    return 2 * (np.random.random(n) - 0.5) * M
    
def log_reg(x, A):
    s = torch.zeros(1)
    for i in range(A.shape[0]):
        s += torch.log(1 + torch.exp(torch.matmul(A[i], x)))
    return s

def grad_logreg(x, A):
    grad = torch.zeros(n)
    for i in range(A.shape[0]):
        Ai_x = torch.matmul(A[i], x)
        exp_Ai_x = torch.exp(Ai_x)
        grad += exp_Ai_x / (1 + exp_Ai_x) * A[i]
    return grad

def L_logreg(A):
    matr = torch.zeros([A.shape[1], A.shape[1]])
    for k in range(A.shape[0]):
        a_ = A[k]
        for i in range(A.shape[1]):
            for j in range(0, A.shape[1]):
                matr[i][j] += a_[i] * a_[j]   
    return matr.norm()

def L3_logreg(A):
    tens4 = torch.zeros([A.shape[1], A.shape[1], A.shape[1], A.shape[1]])
    for k in range(A.shape[0]):
        tens = torch.zeros([A.shape[1], A.shape[1], A.shape[1], A.shape[1]])
        for i in range(A.shape[1]):
            tens3 = torch.zeros([A.shape[1], A.shape[1], A.shape[1]])
            for j in range(A.shape[1]):
                tens2 = torch.zeros([A.shape[1], A.shape[1]])
                for l in range(A.shape[1]):
                    for m in range(A.shape[1]):
                        tens2[i][j] = A[k][i] * A[k][j] 
                tens3[j] = tens2
            tens[i] = tens3             
        tens4 += tens
    return tens4.norm()

# %%
class Iterations:
    def __init__(self, x, iters):
        self.x = x
        self.iters = iters
        
def caution(x):
    if(x.requires_grad):
        print('Input should not require grad')
        return True
    return False

def gradient(f, x):
    if(caution(x)):
        return
    x = torch.tensor(x, requires_grad = True)
    return torch.autograd.grad(outputs = f(x), inputs = x)[0].detach()

def gradient2(f, x):
    if(caution(x)):
        return
    x = torch.tensor(x, requires_grad = True)
    grad = torch.autograd.grad(outputs = f(x), inputs = x, create_graph = True)[0]
    grad2 = torch.zeros([x.shape[0], x.shape[0]])
    for i in range(x.shape[0]):
        grad2[i] = torch.autograd.grad(outputs = grad[i], inputs = x, create_graph = True)[0]
    return grad2.detach()

def gradient3(f, x):
    if(caution(x)):
        return
    x = torch.tensor(x, requires_grad = True)
    grad = torch.autograd.grad(outputs = f(x), inputs = x, create_graph = True)[0]
    grad2 = torch.zeros([x.shape[0], x.shape[0]])
    for i in range(x.shape[0]):
        grad2[i] = torch.autograd.grad(outputs = grad[i], inputs = x, create_graph = True)[0]
    grad3 = torch.zeros([x.shape[0], x.shape[0], x.shape[0]])
    for i in range(x.shape[0]):
        for j in range(x.shape[0]):
            grad3[i][j] = torch.autograd.grad(outputs = grad2[i][j], inputs = x, create_graph = True)[0]
    return grad3.detach()

# %%
def NAG(f, x_0, gradient, L, eps = 1e-10, max_iter = 1e5):
    iterations = [x_0]
    k = 0
    y_0 = x_0
    gradient_x0 = gradient(x_0)
    
    while(len(iterations) <= max_iter):
        if(gradient_x0.norm() <= eps):
            break
        k += 1
        
        x_k = y_0 - 1./L * gradient(y_0)
        y_k = x_k + (k - 1.)/(k + 2.) * (x_k - x_0)
        
        if(f(x_k) > f(x_0) + torch.matmul(gradient_x0, x_k - x_0) + L/2. * (x_k - x_0).norm()):
            L *= 2
            k -= 1
            continue 
            
        iterations.append(x_k)
        gradient_x0 = gradient(x_k)
        x_0 = x_k
        y_0 = y_k
        
    if(len(iterations) >= max_iter):
        print('NAG did not manage to find precise enough solution')      
    return Iterations(x_k, iterations)

# %%
def fNAG(f, x_0, gradient, stop_cr, L, max_iter = 1e5):
    f_opt, eps = stop_cr
    iterations = [x_0]
    k = 0
    y_0 = x_0
    
    while(len(iterations) <= max_iter):
        if(abs(f(x_0) - f_opt) <= eps):
            break
        k += 1
        
        x_k = y_0 - 1./L * gradient(y_0)
        y_k = x_k + (k - 1.)/(k + 2.) * (x_k - x_0)
        
        iterations.append(x_k)
        x_0 = x_k
        y_0 = y_k
        
    if(len(iterations) >= max_iter):
        print('fNAG did not manage to find precise enough solution')   
    return Iterations(x_k, iterations)

# %%
def b_r(x, y, x_k, L_3, grad_r_x, grad2_f_xk):
    def r(x):   
        return 0.5 * torch.matmul(torch.matmul(grad2_f_xk, x - x_k), x - x_k) + L_3 * (x - x_k).norm()**4 / 4. 
    
    return r(y) - r(x) - torch.matmul(grad_r_x, y - x)

def g_phi_tau(y, f, x, grad_f_x, grad2_f_x, tau, L_3):
    
    return grad_f_x + torch.matmul(grad2_f_x, y - x) + 0.5 * 1./tau**2 * (
    gradient(f, x + tau * (y - x)) + gradient(f, x - tau * (y - x)) - 2. * grad_f_x
    ) + L_3 * (y - x).norm()**2 * (y - x)

def g_phi(y, f, x, L_3):
    
    return gradient(f, x) + torch.matmul(gradient2(f, x), y - x) + 0.5 * torch.matmul(torch.matmul(
    gradient3(f, x), y - x), y - x
    ) + L_3 * (y - x).norm()**2 * (y - x)
    
def model(y, f, x, L_3):
    
    return torch.matmul(gradient(f, x), y - x) +  1./2 * torch.matmul(torch.matmul(
    gradient2(f, x), y - x), y - x) + 1./6 * torch.matmul(torch.matmul(torch.matmul(
    gradient3(f, x), y - x), y - x), y - x) + L_3/(4.) * (y - x).norm()**4

# %%
def BDGM_oracle_factor(len_iters):
    return n + 1 + 3 * len_iters

def NAG_oracle_factor(len_iters):
    return 1 * len_iters

def HyperFast_oracle_factor(len_iters, BDGM_iters):
    return 1 + BDGM_oracle_factor(BDGM_iters) + 1 * len_iters

# %%
def BDGM(f, x, L_3, tau, axil_eps, axil_iter, max_iter = 3e2):
    iterations = []
    grad2_f_x = gradient2(f, x)
    grad_f_x = gradient(f, x)
    y_k = x
    S = 2. * ((2 + 2**0.5) / L_3 * grad_f_x.norm())**(1./3)
    delt = 1e-6
    ###delt = eps**1.5 / (grad_f_x.norm()**0.5 + grad2_f_x.norm()**1.5 / L_3**0.5)
    ###tau = 3. * delt / (8 * (2 + 2**0.5) * grad_f_x.norm())
    L = 1.
    while(len(iterations) <= max_iter):
        iterations.append(y_k)
        
        g = g_phi_tau(y_k, f, x, grad_f_x, grad2_f_x, tau, L_3)
        grad_f_yk = gradient(f, y_k)
        if((g.norm() <= 1./6 * grad_f_yk.norm() - delt) | (1./6 * grad_f_yk.norm() - delt <= 0)):
            break
              
        grad_r_yk = torch.matmul(grad2_f_x, y_k - x) + L_3 * (y_k - x).norm()**2 * (y_k - x)
        g_br = lambda y: torch.matmul(g, y - y_k) + 2 * (1 + 1./2**0.5) * b_r(y_k, y, x, L_3, grad_r_yk, grad2_f_x)
        grad_g_br = lambda y: g + 2 * (1 + 1./2**0.5) * (
            torch.matmul(grad2_f_x, y - x) + L_3 * (y - x).norm()**2 * (y - x) - grad_r_yk)
        
        nag_out = NAG(f = g_br, x_0 = y_k, gradient = grad_g_br, L = L, eps = axil_eps, max_iter = axil_iter)
        while(len(nag_out.iters) >= axil_iter):
            if(L >= 1e6):
                break
            L *= 10
            nag_out = NAG(f = g_br, x_0 = y_k, gradient = grad_g_br, L = L, eps = axil_eps, max_iter = axil_iter)
            
        y_k = nag_out.x
        if((y_k - x).norm() > S):
            print('Solution of axiliary problem is beyond the feasible set BDGM')
            
    if(len(iterations) >= max_iter):
            print('BDGM did not manage to find precise enough solution')
    return Iterations(y_k, iterations)

# %%
def bin_srch(f, x_bound, y_bound, max_iter = 20):
    iterations = []
    x_0, x_1 = x_bound
    y_0, y_1 = y_bound
    
    while(len(iterations) <= max_iter):
        x = (x_0 + x_1) / 2.
        f_x = f(x)
        iterations.append(x)
        if(f_x >= y_0):
            if(f_x <= y_1):
                if(len(iterations) >= max_iter):
                    print('bin_srch function has failed')
                return Iterations(x, iterations)
            else:
                x_0 = x
        else:
            x_1 = x

# %%
def HyperFast(f, L_3, tau, stop_cr, axil_eps, axil_iter, max_iter):
    f_opt, eps = stop_cr
    BDGM_iters = []
    def BDGM_(x, axil_eps = axil_eps, axil_iter = axil_iter):
        iters = BDGM(f, x, L_3, tau, axil_eps, axil_iter)
        BDGM_iters.append(len(iters.iters))
        return iters.x
    iterations = []
    A_k = 0.
    y_k = x_k = x_k_v = torch.zeros(n)
    
    y_k = BDGM_(x_k_v)
    lam_k = (7./12) / (0.75 * L_3 * (y_k - x_k_v).norm()**2)         
    a_k = 0.5 * (lam_k + (lam_k**2 + 4 * lam_k * A_k)**0.5)
    A_k = A_k + a_k
    x_k = x_k - a_k * gradient(f, y_k)
    iterations.append(y_k)
    
    while(len(iterations) <= max_iter):  
        xi_t = lambda t: (1 - t)**2 * A_k * (1.5 * L_3) / (2 * t) * (
            BDGM_((1 - t) * x_k + t * y_k) - ((1 - t) * x_k + t * y_k)).norm()**2
        t = bin_srch(xi_t, [0., 1.], [0.5, 0.75]).x
        
        x_k_v = (1 - t) * x_k + t * y_k
        y_k = BDGM_(x_k_v)
        lam_k = (1 - t)**2 * A_k / t
        
        C = (lam_k * 0.75 * L_3 * (y_k - x_k_v).norm()**2)
        if((C < 0.5) | (C > 0.75)):
            print('Wrong lambda parameter was found during the work of HyperFast')
            continue
        
        a_k = 0.5 * (lam_k + (lam_k**2 + 4 * lam_k * A_k)**0.5)
        A_k = A_k + a_k
        x_k = x_k - a_k * gradient(f, y_k)
        
        iterations.append(y_k)
        if(len(iterations) % 10 == 0):
            print(len(iterations), f(y_k), f_opt)
        if(abs(f(y_k) - f_opt) <= eps):
            break
    
    if(len(iterations) >= max_iter):
        print('HyperFast did not manage to find precise enough solution')
    return Iterations(y_k, iterations), sum(BDGM_iters)

# %%
ns = range(10, 201)[::10]
tau = 0.0002
eps = 1e-4
max_iter = 5e2
axil_eps = 1e-10
axil_iter = 3e3
nag_oracle_compl = []
hf_oracle_compl = []

for n in ns:
    len_nag_iters = []
    len_hf_iters = []
    
    for i in range(10):
    
        x_0 = torch.tensor(random(n))
        m = n
        A = torch.zeros([m, n])
        for i in range(0, m):
            A[i] = torch.tensor(random(n, M = 1))
        f = lambda x: log_reg(x, A)
        grad_f = lambda x: grad_logreg(x, A)
        L = L_logreg(A)
        L_3 = 1. ###

        x_opt = NAG(f, x_0, grad_f, L = L, eps = 1e-8, max_iter = 1e5).x
        f_opt = f(x_opt)
        stop_cr = (f_opt, eps)

        nag_iters = fNAG(f, x_0, grad_f, stop_cr, L = L)
        hf_iters, BDGM_iters = HyperFast(f, L_3, tau, stop_cr, axil_eps, axil_iter, max_iter)

        len_nag_iters.append(NAG_oracle_factor(len(nag_iters.iters)))
        len_hf_iters.append(HyperFast_oracle_factor(len(hf_iters.iters), BDGM_iters))
        
    
    nag_oracle_compl.append([np.mean(len_nag_iters), np.std(len_nag_iters)])
    hf_oracle_compl.append([np.mean(len_hf_iters), np.std(len_hf_iters)])
    print("Iteration complete")
    
    print(n, nag_oracle_compl[-1], hf_oracle_compl[-1])
# Out:
# NAG did not manage to find precise enough solution
# 10 tensor([0.3657]) tensor([9.3142e-08])
# 20 tensor([0.0281]) tensor([9.3142e-08])
# 30 tensor([0.0047]) tensor([9.3142e-08])
# 40 tensor([0.0012]) tensor([9.3142e-08])
# 50 tensor([0.0004]) tensor([9.3142e-08])
# 60 tensor([0.0002]) tensor([9.3142e-08])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.1033]) tensor([3.1812e-08])
# 20 tensor([0.0056]) tensor([3.1812e-08])
# 30 tensor([0.0009]) tensor([3.1812e-08])
# 40 tensor([0.0002]) tensor([3.1812e-08])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.1220]) tensor([3.8760e-08])
# 20 tensor([0.0067]) tensor([3.8760e-08])
# 30 tensor([0.0010]) tensor([3.8760e-08])
# 40 tensor([0.0003]) tensor([3.8760e-08])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.0326]) tensor([1.8057e-08])
# 20 tensor([0.0016]) tensor([1.8057e-08])
# 30 tensor([0.0002]) tensor([1.8057e-08])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.0313]) tensor([1.8494e-08])
# 20 tensor([0.0017]) tensor([1.8494e-08])
# 30 tensor([0.0002]) tensor([1.8494e-08])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.3831]) tensor([9.2041e-08])
# NAG did not manage to find precise enough solution
# 20 tensor([0.0257]) tensor([9.2041e-08])
# 30 tensor([0.0042]) tensor([9.2041e-08])
# 40 tensor([0.0011]) tensor([9.2041e-08])
# 50 tensor([0.0004]) tensor([9.2041e-08])
# 60 tensor([0.0002]) tensor([9.2041e-08])
# NAG did not manage to find precise enough solution
# 10 tensor([0.5496]) tensor([1.3799e-07])
# 20 tensor([0.0433]) tensor([1.3799e-07])
# 30 tensor([0.0072]) tensor([1.3799e-07])
# 40 tensor([0.0019]) tensor([1.3799e-07])
# 50 tensor([0.0007]) tensor([1.3799e-07])
# 60 tensor([0.0003]) tensor([1.3799e-07])
# 70 tensor([0.0001]) tensor([1.3799e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.0200]) tensor([1.6281e-08])
# 20 tensor([0.0009]) tensor([1.6281e-08])
# 30 tensor([0.0001]) tensor([1.6281e-08])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.1595]) tensor([5.6337e-08])
# 20 tensor([0.0097]) tensor([5.6337e-08])
# 30 tensor([0.0015]) tensor([5.6337e-08])
# 40 tensor([0.0004]) tensor([5.6337e-08])
# 50 tensor([0.0001]) tensor([5.6337e-08])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.5236]) tensor([1.4103e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 20 tensor([0.0397]) tensor([1.4103e-07])
# 30 tensor([0.0066]) tensor([1.4103e-07])
# 40 tensor([0.0018]) tensor([1.4103e-07])
# 50 tensor([0.0006]) tensor([1.4103e-07])
# 60 tensor([0.0003]) tensor([1.4103e-07])
# 70 tensor([0.0001]) tensor([1.4103e-07])
# Iteration complete
# 10 [2367.3, 920.8390793184225] [5915.0, 1963.4365790623337]
# NAG did not manage to find precise enough solution
# 10 tensor([0.4370]) tensor([3.0337e-07])
# NAG did not manage to find precise enough solution
# 20 tensor([0.0301]) tensor([3.0337e-07])
# 30 tensor([0.0048]) tensor([3.0337e-07])
# 40 tensor([0.0012]) tensor([3.0337e-07])
# 50 tensor([0.0004]) tensor([3.0337e-07])
# 60 tensor([0.0002]) tensor([3.0337e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.1979]) tensor([1.4666e-07])
# 20 tensor([0.0107]) tensor([1.4666e-07])
# 30 tensor([0.0016]) tensor([1.4666e-07])
# 40 tensor([0.0004]) tensor([1.4666e-07])
# 50 tensor([0.0001]) tensor([1.4666e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.3427]) tensor([2.2368e-07])
# 20 tensor([0.0201]) tensor([2.2368e-07])
# 30 tensor([0.0031]) tensor([2.2368e-07])
# 40 tensor([0.0008]) tensor([2.2368e-07])
# 50 tensor([0.0003]) tensor([2.2368e-07])
# 60 tensor([0.0001]) tensor([2.2368e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.1513]) tensor([1.2611e-07])
# 20 tensor([0.0083]) tensor([1.2611e-07])
# 30 tensor([0.0013]) tensor([1.2611e-07])
# 40 tensor([0.0003]) tensor([1.2611e-07])
# 50 tensor([0.0001]) tensor([1.2611e-07])
# NAG did not manage to find precise enough solution
# 10 tensor([0.1419]) tensor([1.2765e-07])
# 20 tensor([0.0082]) tensor([1.2765e-07])
# 30 tensor([0.0013]) tensor([1.2765e-07])
# 40 tensor([0.0003]) tensor([1.2765e-07])
# 50 tensor([0.0001]) tensor([1.2765e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.1518]) tensor([1.4725e-07])
# 20 tensor([0.0091]) tensor([1.4725e-07])
# 30 tensor([0.0014]) tensor([1.4725e-07])
# 40 tensor([0.0003]) tensor([1.4725e-07])
# 50 tensor([0.0001]) tensor([1.4725e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.2876]) tensor([2.0712e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 20 tensor([0.0170]) tensor([2.0712e-07])
# 30 tensor([0.0026]) tensor([2.0712e-07])
# 40 tensor([0.0006]) tensor([2.0712e-07])
# 50 tensor([0.0002]) tensor([2.0712e-07])
# NAG did not manage to find precise enough solution
# 10 tensor([0.1994]) tensor([1.6476e-07])
# 20 tensor([0.0114]) tensor([1.6476e-07])
# 30 tensor([0.0017]) tensor([1.6476e-07])
# 40 tensor([0.0004]) tensor([1.6476e-07])
# 50 tensor([0.0001]) tensor([1.6476e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([1.3393]) tensor([7.2355e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 20 tensor([0.1167]) tensor([7.2355e-07])
# 30 tensor([0.0202]) tensor([7.2355e-07])
# 40 tensor([0.0054]) tensor([7.2355e-07])
# 50 tensor([0.0019]) tensor([7.2355e-07])
# 60 tensor([0.0008]) tensor([7.2355e-07])
# 70 tensor([0.0003]) tensor([7.2355e-07])
# 80 tensor([0.0002]) tensor([7.2355e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.0677]) tensor([8.4127e-08])
# 20 tensor([0.0037]) tensor([8.4127e-08])
# 30 tensor([0.0005]) tensor([8.4127e-08])
# 40 tensor([0.0001]) tensor([8.4127e-08])
# Iteration complete
# 20 [4498.5, 1495.1260983609375] [6351.9, 1636.7046434833621]
# NAG did not manage to find precise enough solution
# 10 tensor([1.2644]) tensor([9.3908e-07])
# 20 tensor([0.0877]) tensor([9.3908e-07])
# 30 tensor([0.0142]) tensor([9.3908e-07])
# 40 tensor([0.0038]) tensor([9.3908e-07])
# 50 tensor([0.0013]) tensor([9.3908e-07])
# 60 tensor([0.0005]) tensor([9.3908e-07])
# 70 tensor([0.0002]) tensor([9.3908e-07])
# 80 tensor([0.0001]) tensor([9.3908e-07])
# NAG did not manage to find precise enough solution
# 10 tensor([0.3906]) tensor([4.4548e-07])
# NAG did not manage to find precise enough solution
# 20 tensor([0.0231]) tensor([4.4548e-07])
# 30 tensor([0.0036]) tensor([4.4548e-07])
# 40 tensor([0.0009]) tensor([4.4548e-07])
# 50 tensor([0.0003]) tensor([4.4548e-07])
# 60 tensor([0.0001]) tensor([4.4548e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.5197]) tensor([4.8421e-07])
# NAG did not manage to find precise enough solution
# 20 tensor([0.0311]) tensor([4.8421e-07])
# 30 tensor([0.0047]) tensor([4.8421e-07])
# 40 tensor([0.0012]) tensor([4.8421e-07])
# 50 tensor([0.0004]) tensor([4.8421e-07])
# 60 tensor([0.0001]) tensor([4.8421e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([1.2367]) tensor([9.9431e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 20 tensor([0.0834]) tensor([9.9431e-07])
# 30 tensor([0.0137]) tensor([9.9431e-07])
# 40 tensor([0.0036]) tensor([9.9431e-07])
# 50 tensor([0.0013]) tensor([9.9431e-07])
# 60 tensor([0.0005]) tensor([9.9431e-07])
# 70 tensor([0.0002]) tensor([9.9431e-07])
# 80 tensor([0.0001]) tensor([9.9431e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.1141]) tensor([2.0000e-07])
# 20 tensor([0.0061]) tensor([2.0000e-07])
# 30 tensor([0.0009]) tensor([2.0000e-07])
# 40 tensor([0.0002]) tensor([2.0000e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.0614]) tensor([1.2911e-07])
# 20 tensor([0.0029]) tensor([1.2911e-07])
# 30 tensor([0.0004]) tensor([1.2911e-07])
# 40 tensor([0.0001]) tensor([1.2911e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.8769]) tensor([8.1395e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 20 tensor([0.0560]) tensor([8.1395e-07])
# 30 tensor([0.0089]) tensor([8.1395e-07])
# 40 tensor([0.0023]) tensor([8.1395e-07])
# 50 tensor([0.0008]) tensor([8.1395e-07])
# 60 tensor([0.0003]) tensor([8.1395e-07])
# 70 tensor([0.0001]) tensor([8.1395e-07])
# NAG did not manage to find precise enough solution
# 10 tensor([0.2235]) tensor([3.1266e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 20 tensor([0.0123]) tensor([3.1266e-07])
# 30 tensor([0.0019]) tensor([3.1266e-07])
# 40 tensor([0.0005]) tensor([3.1266e-07])
# 50 tensor([0.0002]) tensor([3.1266e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.6452]) tensor([5.9304e-07])
# NAG did not manage to find precise enough solution
# 20 tensor([0.0412]) tensor([5.9304e-07])
# 30 tensor([0.0065]) tensor([5.9304e-07])
# 40 tensor([0.0017]) tensor([5.9304e-07])
# 50 tensor([0.0006]) tensor([5.9304e-07])
# 60 tensor([0.0002]) tensor([5.9304e-07])
# 70 tensor([0.0001]) tensor([5.9304e-07])
# NAG did not manage to find precise enough solution
# 10 tensor([0.5085]) tensor([5.3807e-07])
# 20 tensor([0.0306]) tensor([5.3807e-07])
# 30 tensor([0.0050]) tensor([5.3807e-07])
# 40 tensor([0.0013]) tensor([5.3807e-07])
# 50 tensor([0.0004]) tensor([5.3807e-07])
# 60 tensor([0.0002]) tensor([5.3807e-07])
# Iteration complete
# 30 [7076.7, 2008.2696556986564] [7378.5, 1790.6644716417422]
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.5096]) tensor([7.4016e-07])
# 20 tensor([0.0286]) tensor([7.4016e-07])
# 30 tensor([0.0044]) tensor([7.4016e-07])
# 40 tensor([0.0011]) tensor([7.4016e-07])
# 50 tensor([0.0003]) tensor([7.4016e-07])
# 60 tensor([0.0001]) tensor([7.4016e-07])
# NAG did not manage to find precise enough solution
# 10 tensor([0.5885]) tensor([7.6860e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 20 tensor([0.0343]) tensor([7.6860e-07])
# 30 tensor([0.0053]) tensor([7.6860e-07])
# 40 tensor([0.0013]) tensor([7.6860e-07])
# 50 tensor([0.0004]) tensor([7.6860e-07])
# 60 tensor([0.0002]) tensor([7.6860e-07])
# NAG did not manage to find precise enough solution
# 10 tensor([0.1231]) tensor([3.1645e-07])
# 20 tensor([0.0064]) tensor([3.1645e-07])
# 30 tensor([0.0009]) tensor([3.1645e-07])
# 40 tensor([0.0002]) tensor([3.1645e-07])
# NAG did not manage to find precise enough solution
# 10 tensor([0.6717]) tensor([9.1355e-07])
# 20 tensor([0.0411]) tensor([9.1355e-07])
# 30 tensor([0.0065]) tensor([9.1355e-07])
# 40 tensor([0.0017]) tensor([9.1355e-07])
# 50 tensor([0.0006]) tensor([9.1355e-07])
# 60 tensor([0.0002]) tensor([9.1355e-07])
# 70 tensor([0.0001]) tensor([9.1355e-07])
# NAG did not manage to find precise enough solution
# 10 tensor([0.5613]) tensor([7.6643e-07])
# 20 tensor([0.0311]) tensor([7.6643e-07])
# 30 tensor([0.0048]) tensor([7.6643e-07])
# 40 tensor([0.0012]) tensor([7.6643e-07])
# 50 tensor([0.0004]) tensor([7.6643e-07])
# 60 tensor([0.0001]) tensor([7.6643e-07])
# NAG did not manage to find precise enough solution
# 10 tensor([0.1596]) tensor([3.5376e-07])
# 20 tensor([0.0082]) tensor([3.5376e-07])
# 30 tensor([0.0012]) tensor([3.5376e-07])
# 40 tensor([0.0003]) tensor([3.5376e-07])
# 50 tensor([0.0001]) tensor([3.5376e-07])
# NAG did not manage to find precise enough solution
# 10 tensor([0.4715]) tensor([7.3751e-07])
# 20 tensor([0.0283]) tensor([7.3751e-07])
# 30 tensor([0.0043]) tensor([7.3751e-07])
# 40 tensor([0.0011]) tensor([7.3751e-07])
# 50 tensor([0.0003]) tensor([7.3751e-07])
# 60 tensor([0.0001]) tensor([7.3751e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([1.0898]) tensor([1.3032e-06])
# 20 tensor([0.0701]) tensor([1.3032e-06])
# 30 tensor([0.0111]) tensor([1.3032e-06])
# 40 tensor([0.0028]) tensor([1.3032e-06])
# 50 tensor([0.0010]) tensor([1.3032e-06])
# 60 tensor([0.0004]) tensor([1.3032e-06])
# 70 tensor([0.0002]) tensor([1.3032e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.6580]) tensor([8.6643e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 20 tensor([0.0389]) tensor([8.6643e-07])
# 30 tensor([0.0059]) tensor([8.6643e-07])
# 40 tensor([0.0015]) tensor([8.6643e-07])
# 50 tensor([0.0005]) tensor([8.6643e-07])
# 60 tensor([0.0002]) tensor([8.6643e-07])
# NAG did not manage to find precise enough solution
# 10 tensor([0.3330]) tensor([5.6738e-07])
# 20 tensor([0.0187]) tensor([5.6738e-07])
# 30 tensor([0.0029]) tensor([5.6738e-07])
# 40 tensor([0.0007]) tensor([5.6738e-07])
# 50 tensor([0.0002]) tensor([5.6738e-07])
# Iteration complete
# 40 [8375.9, 1597.4185706946068] [7238.2, 1198.4170225760313]
# NAG did not manage to find precise enough solution
# 10 tensor([2.3004]) tensor([3.1048e-06])
# 20 tensor([0.1627]) tensor([3.1048e-06])
# 30 tensor([0.0263]) tensor([3.1048e-06])
# 40 tensor([0.0070]) tensor([3.1048e-06])
# 50 tensor([0.0024]) tensor([3.1048e-06])
# 60 tensor([0.0010]) tensor([3.1048e-06])
# 70 tensor([0.0004]) tensor([3.1048e-06])
# 80 tensor([0.0002]) tensor([3.1048e-06])
# 90 tensor([0.0001]) tensor([3.1048e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.2381]) tensor([6.1740e-07])
# NAG did not manage to find precise enough solution
# 20 tensor([0.0125]) tensor([6.1740e-07])
# 30 tensor([0.0018]) tensor([6.1740e-07])
# 40 tensor([0.0004]) tensor([6.1740e-07])
# 50 tensor([0.0001]) tensor([6.1740e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([2.4304]) tensor([3.1130e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 20 tensor([0.1755]) tensor([3.1130e-06])
# 30 tensor([0.0284]) tensor([3.1130e-06])
# 40 tensor([0.0076]) tensor([3.1130e-06])
# 50 tensor([0.0026]) tensor([3.1130e-06])
# 60 tensor([0.0010]) tensor([3.1130e-06])
# 70 tensor([0.0005]) tensor([3.1130e-06])
# 80 tensor([0.0002]) tensor([3.1130e-06])
# 90 tensor([0.0001]) tensor([3.1130e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.3048]) tensor([7.2396e-07])
# 20 tensor([0.0158]) tensor([7.2396e-07])
# 30 tensor([0.0024]) tensor([7.2396e-07])
# 40 tensor([0.0006]) tensor([7.2396e-07])
# 50 tensor([0.0002]) tensor([7.2396e-07])
# NAG did not manage to find precise enough solution
# 10 tensor([0.2783]) tensor([7.0195e-07])
# 20 tensor([0.0155]) tensor([7.0195e-07])
# 30 tensor([0.0024]) tensor([7.0195e-07])
# 40 tensor([0.0006]) tensor([7.0195e-07])
# 50 tensor([0.0002]) tensor([7.0195e-07])
# NAG did not manage to find precise enough solution
# 10 tensor([1.6715]) tensor([2.3256e-06])
# 20 tensor([0.1116]) tensor([2.3256e-06])
# 30 tensor([0.0177]) tensor([2.3256e-06])
# 40 tensor([0.0045]) tensor([2.3256e-06])
# 50 tensor([0.0016]) tensor([2.3256e-06])
# 60 tensor([0.0006]) tensor([2.3256e-06])
# 70 tensor([0.0003]) tensor([2.3256e-06])
# 80 tensor([0.0001]) tensor([2.3256e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.2929]) tensor([7.3069e-07])
# 20 tensor([0.0155]) tensor([7.3069e-07])
# 30 tensor([0.0024]) tensor([7.3069e-07])
# 40 tensor([0.0006]) tensor([7.3069e-07])
# 50 tensor([0.0002]) tensor([7.3069e-07])
# NAG did not manage to find precise enough solution
# 10 tensor([0.2369]) tensor([6.3075e-07])
# 20 tensor([0.0123]) tensor([6.3075e-07])
# 30 tensor([0.0018]) tensor([6.3075e-07])
# 40 tensor([0.0004]) tensor([6.3075e-07])
# 50 tensor([0.0001]) tensor([6.3075e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.2483]) tensor([6.7459e-07])
# NAG did not manage to find precise enough solution
# 20 tensor([0.0129]) tensor([6.7459e-07])
# 30 tensor([0.0020]) tensor([6.7459e-07])
# 40 tensor([0.0005]) tensor([6.7459e-07])
# 50 tensor([0.0002]) tensor([6.7459e-07])
# NAG did not manage to find precise enough solution
# 10 tensor([0.2520]) tensor([6.4604e-07])
# 20 tensor([0.0132]) tensor([6.4604e-07])
# 30 tensor([0.0019]) tensor([6.4604e-07])
# 40 tensor([0.0005]) tensor([6.4604e-07])
# 50 tensor([0.0001]) tensor([6.4604e-07])
# Iteration complete
# 50 [10705.1, 3906.664010380212] [7634.1, 2215.9609405402434]
# NAG did not manage to find precise enough solution
# 10 tensor([0.4834]) tensor([1.3568e-06])
# 20 tensor([0.0274]) tensor([1.3568e-06])
# 30 tensor([0.0042]) tensor([1.3568e-06])
# 40 tensor([0.0010]) tensor([1.3568e-06])
# 50 tensor([0.0003]) tensor([1.3568e-06])
# 60 tensor([0.0001]) tensor([1.3568e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.5573]) tensor([1.3308e-06])
# NAG did not manage to find precise enough solution
# 20 tensor([0.0311]) tensor([1.3308e-06])
# 30 tensor([0.0048]) tensor([1.3308e-06])
# 40 tensor([0.0012]) tensor([1.3308e-06])
# 50 tensor([0.0004]) tensor([1.3308e-06])
# 60 tensor([0.0001]) tensor([1.3308e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.1798]) tensor([6.6766e-07])
# 20 tensor([0.0093]) tensor([6.6766e-07])
# 30 tensor([0.0014]) tensor([6.6766e-07])
# 40 tensor([0.0003]) tensor([6.6766e-07])
# 50 tensor([0.0001]) tensor([6.6766e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.5781]) tensor([1.3896e-06])
# 20 tensor([0.0323]) tensor([1.3896e-06])
# 30 tensor([0.0050]) tensor([1.3896e-06])
# 40 tensor([0.0012]) tensor([1.3896e-06])
# 50 tensor([0.0004]) tensor([1.3896e-06])
# 60 tensor([0.0001]) tensor([1.3896e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.3331]) tensor([9.8200e-07])
# NAG did not manage to find precise enough solution
# 20 tensor([0.0173]) tensor([9.8200e-07])
# 30 tensor([0.0025]) tensor([9.8200e-07])
# 40 tensor([0.0006]) tensor([9.8200e-07])
# 50 tensor([0.0002]) tensor([9.8200e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.2541]) tensor([8.2640e-07])
# 20 tensor([0.0133]) tensor([8.2640e-07])
# 30 tensor([0.0020]) tensor([8.2640e-07])
# 40 tensor([0.0005]) tensor([8.2640e-07])
# 50 tensor([0.0001]) tensor([8.2640e-07])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.4811]) tensor([1.2603e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 20 tensor([0.0272]) tensor([1.2603e-06])
# 30 tensor([0.0042]) tensor([1.2603e-06])
# 40 tensor([0.0010]) tensor([1.2603e-06])
# 50 tensor([0.0003]) tensor([1.2603e-06])
# 60 tensor([0.0001]) tensor([1.2603e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.4001]) tensor([1.0823e-06])
# 20 tensor([0.0208]) tensor([1.0823e-06])
# 30 tensor([0.0032]) tensor([1.0823e-06])
# 40 tensor([0.0008]) tensor([1.0823e-06])
# 50 tensor([0.0003]) tensor([1.0823e-06])
# 60 tensor([0.0001]) tensor([1.0823e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([1.2355]) tensor([2.4065e-06])
# 20 tensor([0.0765]) tensor([2.4065e-06])
# 30 tensor([0.0122]) tensor([2.4065e-06])
# 40 tensor([0.0031]) tensor([2.4065e-06])
# 50 tensor([0.0010]) tensor([2.4065e-06])
# 60 tensor([0.0004]) tensor([2.4065e-06])
# 70 tensor([0.0002]) tensor([2.4065e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.1840]) tensor([6.7990e-07])
# 20 tensor([0.0094]) tensor([6.7990e-07])
# 30 tensor([0.0014]) tensor([6.7990e-07])
# 40 tensor([0.0003]) tensor([6.7990e-07])
# 50 tensor([0.0001]) tensor([6.7990e-07])
# Iteration complete
# 60 [10680.0, 2004.555761259836] [6875.6, 1082.1876177447236]
# NAG did not manage to find precise enough solution
# 10 tensor([0.5938]) tensor([1.6543e-06])
# 20 tensor([0.0322]) tensor([1.6543e-06])
# 30 tensor([0.0049]) tensor([1.6543e-06])
# 40 tensor([0.0012]) tensor([1.6543e-06])
# 50 tensor([0.0004]) tensor([1.6543e-06])
# 60 tensor([0.0001]) tensor([1.6543e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.2324]) tensor([1.0003e-06])
# 20 tensor([0.0124]) tensor([1.0003e-06])
# 30 tensor([0.0018]) tensor([1.0003e-06])
# 40 tensor([0.0004]) tensor([1.0003e-06])
# 50 tensor([0.0001]) tensor([1.0003e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.4668]) tensor([1.4919e-06])
# 20 tensor([0.0258]) tensor([1.4919e-06])
# 30 tensor([0.0039]) tensor([1.4919e-06])
# 40 tensor([0.0010]) tensor([1.4919e-06])
# 50 tensor([0.0003]) tensor([1.4919e-06])
# 60 tensor([0.0001]) tensor([1.4919e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.3445]) tensor([1.2691e-06])
# 20 tensor([0.0178]) tensor([1.2691e-06])
# 30 tensor([0.0027]) tensor([1.2691e-06])
# 40 tensor([0.0007]) tensor([1.2691e-06])
# 50 tensor([0.0002]) tensor([1.2691e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([1.3293]) tensor([3.0381e-06])
# 20 tensor([0.0804]) tensor([3.0381e-06])
# 30 tensor([0.0124]) tensor([3.0381e-06])
# 40 tensor([0.0031]) tensor([3.0381e-06])
# 50 tensor([0.0011]) tensor([3.0381e-06])
# 60 tensor([0.0004]) tensor([3.0381e-06])
# 70 tensor([0.0002]) tensor([3.0381e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.2375]) tensor([1.0716e-06])
# 20 tensor([0.0127]) tensor([1.0716e-06])
# 30 tensor([0.0019]) tensor([1.0716e-06])
# 40 tensor([0.0005]) tensor([1.0716e-06])
# 50 tensor([0.0001]) tensor([1.0716e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.4918]) tensor([1.5798e-06])
# 20 tensor([0.0275]) tensor([1.5798e-06])
# 30 tensor([0.0043]) tensor([1.5798e-06])
# 40 tensor([0.0010]) tensor([1.5798e-06])
# 50 tensor([0.0003]) tensor([1.5798e-06])
# 60 tensor([0.0001]) tensor([1.5798e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.2389]) tensor([1.0292e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 20 tensor([0.0129]) tensor([1.0292e-06])
# 30 tensor([0.0019]) tensor([1.0292e-06])
# 40 tensor([0.0005]) tensor([1.0292e-06])
# 50 tensor([0.0001]) tensor([1.0292e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.4777]) tensor([1.5675e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 20 tensor([0.0263]) tensor([1.5675e-06])
# 30 tensor([0.0040]) tensor([1.5675e-06])
# 40 tensor([0.0010]) tensor([1.5675e-06])
# 50 tensor([0.0003]) tensor([1.5675e-06])
# 60 tensor([0.0001]) tensor([1.5675e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.2672]) tensor([1.0306e-06])
# 20 tensor([0.0138]) tensor([1.0306e-06])
# 30 tensor([0.0020]) tensor([1.0306e-06])
# 40 tensor([0.0005]) tensor([1.0306e-06])
# 50 tensor([0.0002]) tensor([1.0306e-06])
# Iteration complete
# 70 [11851.4, 2061.589202532842] [6835.4, 956.2337789473868]
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.5526]) tensor([2.0042e-06])
# 20 tensor([0.0290]) tensor([2.0042e-06])
# 30 tensor([0.0044]) tensor([2.0042e-06])
# 40 tensor([0.0011]) tensor([2.0042e-06])
# 50 tensor([0.0004]) tensor([2.0042e-06])
# 60 tensor([0.0001]) tensor([2.0042e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.4273]) tensor([1.7117e-06])
# 20 tensor([0.0224]) tensor([1.7117e-06])
# 30 tensor([0.0034]) tensor([1.7117e-06])
# 40 tensor([0.0008]) tensor([1.7117e-06])
# 50 tensor([0.0003]) tensor([1.7117e-06])
# 60 tensor([0.0001]) tensor([1.7117e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.7510]) tensor([2.4299e-06])
# 20 tensor([0.0415]) tensor([2.4299e-06])
# 30 tensor([0.0064]) tensor([2.4299e-06])
# 40 tensor([0.0016]) tensor([2.4299e-06])
# 50 tensor([0.0005]) tensor([2.4299e-06])
# 60 tensor([0.0002]) tensor([2.4299e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.2691]) tensor([1.3544e-06])
# 20 tensor([0.0143]) tensor([1.3544e-06])
# 30 tensor([0.0021]) tensor([1.3544e-06])
# 40 tensor([0.0005]) tensor([1.3544e-06])
# 50 tensor([0.0002]) tensor([1.3544e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.6229]) tensor([2.2155e-06])
# 20 tensor([0.0352]) tensor([2.2155e-06])
# 30 tensor([0.0054]) tensor([2.2155e-06])
# 40 tensor([0.0013]) tensor([2.2155e-06])
# 50 tensor([0.0004]) tensor([2.2155e-06])
# 60 tensor([0.0002]) tensor([2.2155e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.3947]) tensor([1.6788e-06])
# NAG did not manage to find precise enough solution
# 20 tensor([0.0214]) tensor([1.6788e-06])
# 30 tensor([0.0033]) tensor([1.6788e-06])
# 40 tensor([0.0008]) tensor([1.6788e-06])
# 50 tensor([0.0003]) tensor([1.6788e-06])
# 60 tensor([0.0001]) tensor([1.6788e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.4512]) tensor([1.8299e-06])
# 20 tensor([0.0263]) tensor([1.8299e-06])
# 30 tensor([0.0040]) tensor([1.8299e-06])
# 40 tensor([0.0010]) tensor([1.8299e-06])
# 50 tensor([0.0003]) tensor([1.8299e-06])
# 60 tensor([0.0001]) tensor([1.8299e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.4486]) tensor([1.8266e-06])
# NAG did not manage to find precise enough solution
# 20 tensor([0.0243]) tensor([1.8266e-06])
# 30 tensor([0.0037]) tensor([1.8266e-06])
# 40 tensor([0.0009]) tensor([1.8266e-06])
# 50 tensor([0.0003]) tensor([1.8266e-06])
# 60 tensor([0.0001]) tensor([1.8266e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.6525]) tensor([2.2719e-06])
# 20 tensor([0.0363]) tensor([2.2719e-06])
# 30 tensor([0.0056]) tensor([2.2719e-06])
# 40 tensor([0.0014]) tensor([2.2719e-06])
# 50 tensor([0.0004]) tensor([2.2719e-06])
# 60 tensor([0.0002]) tensor([2.2719e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.5891]) tensor([2.0826e-06])
# 20 tensor([0.0325]) tensor([2.0826e-06])
# 30 tensor([0.0049]) tensor([2.0826e-06])
# 40 tensor([0.0012]) tensor([2.0826e-06])
# 50 tensor([0.0004]) tensor([2.0826e-06])
# 60 tensor([0.0001]) tensor([2.0826e-06])
# Iteration complete
# 80 [13743.2, 1086.3321591483887] [7188.5, 541.9507818981351]
# NAG did not manage to find precise enough solution
# 10 tensor([1.1034]) tensor([3.5817e-06])
# 20 tensor([0.0595]) tensor([3.5817e-06])
# 30 tensor([0.0092]) tensor([3.5817e-06])
# 40 tensor([0.0023]) tensor([3.5817e-06])
# 50 tensor([0.0007]) tensor([3.5817e-06])
# 60 tensor([0.0003]) tensor([3.5817e-06])
# 70 tensor([0.0001]) tensor([3.5817e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.4989]) tensor([2.3477e-06])
# NAG did not manage to find precise enough solution
# 20 tensor([0.0277]) tensor([2.3477e-06])
# 30 tensor([0.0043]) tensor([2.3477e-06])
# 40 tensor([0.0010]) tensor([2.3477e-06])
# 50 tensor([0.0003]) tensor([2.3477e-06])
# 60 tensor([0.0001]) tensor([2.3477e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.4151]) tensor([2.0548e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 20 tensor([0.0219]) tensor([2.0548e-06])
# 30 tensor([0.0033]) tensor([2.0548e-06])
# 40 tensor([0.0008]) tensor([2.0548e-06])
# 50 tensor([0.0003]) tensor([2.0548e-06])
# 60 tensor([0.0001]) tensor([2.0548e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.5025]) tensor([2.3488e-06])
# 20 tensor([0.0281]) tensor([2.3488e-06])
# 30 tensor([0.0043]) tensor([2.3488e-06])
# 40 tensor([0.0011]) tensor([2.3488e-06])
# 50 tensor([0.0003]) tensor([2.3488e-06])
# 60 tensor([0.0001]) tensor([2.3488e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.3939]) tensor([1.9705e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 20 tensor([0.0207]) tensor([1.9705e-06])
# 30 tensor([0.0031]) tensor([1.9705e-06])
# 40 tensor([0.0007]) tensor([1.9705e-06])
# 50 tensor([0.0002]) tensor([1.9705e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.5629]) tensor([2.3680e-06])
# NAG did not manage to find precise enough solution
# 20 tensor([0.0285]) tensor([2.3680e-06])
# 30 tensor([0.0044]) tensor([2.3680e-06])
# 40 tensor([0.0011]) tensor([2.3680e-06])
# 50 tensor([0.0003]) tensor([2.3680e-06])
# 60 tensor([0.0001]) tensor([2.3680e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.2610]) tensor([1.5674e-06])
# 20 tensor([0.0141]) tensor([1.5674e-06])
# 30 tensor([0.0021]) tensor([1.5674e-06])
# 40 tensor([0.0005]) tensor([1.5674e-06])
# 50 tensor([0.0002]) tensor([1.5674e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.5361]) tensor([2.5318e-06])
# 20 tensor([0.0312]) tensor([2.5318e-06])
# 30 tensor([0.0048]) tensor([2.5318e-06])
# 40 tensor([0.0012]) tensor([2.5318e-06])
# 50 tensor([0.0004]) tensor([2.5318e-06])
# 60 tensor([0.0001]) tensor([2.5318e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([1.3014]) tensor([3.9564e-06])
# NAG did not manage to find precise enough solution
# 20 tensor([0.0760]) tensor([3.9564e-06])
# 30 tensor([0.0116]) tensor([3.9564e-06])
# 40 tensor([0.0028]) tensor([3.9564e-06])
# 50 tensor([0.0009]) tensor([3.9564e-06])
# 60 tensor([0.0004]) tensor([3.9564e-06])
# 70 tensor([0.0002]) tensor([3.9564e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.5750]) tensor([2.3943e-06])
# 20 tensor([0.0306]) tensor([2.3943e-06])
# 30 tensor([0.0047]) tensor([2.3943e-06])
# 40 tensor([0.0011]) tensor([2.3943e-06])
# 50 tensor([0.0004]) tensor([2.3943e-06])
# 60 tensor([0.0001]) tensor([2.3943e-06])
# Iteration complete
# 90 [15502.8, 1993.1504107818857] [7411.9, 855.2938033214084]
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.7014]) tensor([3.3020e-06])
# 20 tensor([0.0397]) tensor([3.3020e-06])
# 30 tensor([0.0061]) tensor([3.3020e-06])
# 40 tensor([0.0015]) tensor([3.3020e-06])
# 50 tensor([0.0005]) tensor([3.3020e-06])
# 60 tensor([0.0002]) tensor([3.3020e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.2040]) tensor([1.4707e-06])
# 20 tensor([0.0098]) tensor([1.4707e-06])
# 30 tensor([0.0014]) tensor([1.4707e-06])
# 40 tensor([0.0003]) tensor([1.4707e-06])
# 50 tensor([0.0001]) tensor([1.4707e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.7562]) tensor([3.3210e-06])
# 20 tensor([0.0423]) tensor([3.3210e-06])
# 30 tensor([0.0065]) tensor([3.3210e-06])
# 40 tensor([0.0016]) tensor([3.3210e-06])
# 50 tensor([0.0005]) tensor([3.3210e-06])
# 60 tensor([0.0002]) tensor([3.3210e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.8456]) tensor([3.3935e-06])
# 20 tensor([0.0452]) tensor([3.3935e-06])
# 30 tensor([0.0069]) tensor([3.3935e-06])
# 40 tensor([0.0017]) tensor([3.3935e-06])
# 50 tensor([0.0005]) tensor([3.3935e-06])
# 60 tensor([0.0002]) tensor([3.3935e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.4766]) tensor([2.5595e-06])
# 20 tensor([0.0250]) tensor([2.5595e-06])
# 30 tensor([0.0037]) tensor([2.5595e-06])
# 40 tensor([0.0009]) tensor([2.5595e-06])
# 50 tensor([0.0003]) tensor([2.5595e-06])
# 60 tensor([0.0001]) tensor([2.5595e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.6817]) tensor([3.0336e-06])
# NAG did not manage to find precise enough solution
# 20 tensor([0.0358]) tensor([3.0336e-06])
# 30 tensor([0.0055]) tensor([3.0336e-06])
# 40 tensor([0.0013]) tensor([3.0336e-06])
# 50 tensor([0.0004]) tensor([3.0336e-06])
# 60 tensor([0.0002]) tensor([3.0336e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.5152]) tensor([2.8272e-06])
# 20 tensor([0.0288]) tensor([2.8272e-06])
# 30 tensor([0.0044]) tensor([2.8272e-06])
# 40 tensor([0.0011]) tensor([2.8272e-06])
# 50 tensor([0.0003]) tensor([2.8272e-06])
# 60 tensor([0.0001]) tensor([2.8272e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.4509]) tensor([2.4245e-06])
# 20 tensor([0.0236]) tensor([2.4245e-06])
# 30 tensor([0.0035]) tensor([2.4245e-06])
# 40 tensor([0.0008]) tensor([2.4245e-06])
# 50 tensor([0.0003]) tensor([2.4245e-06])
# 60 tensor([0.0001]) tensor([2.4245e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.7420]) tensor([3.3972e-06])
# 20 tensor([0.0418]) tensor([3.3972e-06])
# 30 tensor([0.0064]) tensor([3.3972e-06])
# 40 tensor([0.0016]) tensor([3.3972e-06])
# 50 tensor([0.0005]) tensor([3.3972e-06])
# 60 tensor([0.0002]) tensor([3.3972e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.9167]) tensor([3.6862e-06])
# 20 tensor([0.0513]) tensor([3.6862e-06])
# 30 tensor([0.0079]) tensor([3.6862e-06])
# 40 tensor([0.0019]) tensor([3.6862e-06])
# 50 tensor([0.0006]) tensor([3.6862e-06])
# 60 tensor([0.0002]) tensor([3.6862e-06])
# 70 tensor([0.0001]) tensor([3.6862e-06])
# Iteration complete
# 100 [16777.1, 1895.710655664519] [7437.7, 729.8135446811054]
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.5299]) tensor([3.0914e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 20 tensor([0.0281]) tensor([3.0914e-06])
# 30 tensor([0.0043]) tensor([3.0914e-06])
# 40 tensor([0.0010]) tensor([3.0914e-06])
# 50 tensor([0.0003]) tensor([3.0914e-06])
# 60 tensor([0.0001]) tensor([3.0914e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.3322]) tensor([2.4381e-06])
# NAG did not manage to find precise enough solution
# 20 tensor([0.0179]) tensor([2.4381e-06])
# 30 tensor([0.0026]) tensor([2.4381e-06])
# 40 tensor([0.0006]) tensor([2.4381e-06])
# 50 tensor([0.0002]) tensor([2.4381e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.4403]) tensor([2.6924e-06])
# NAG did not manage to find precise enough solution
# 20 tensor([0.0227]) tensor([2.6924e-06])
# 30 tensor([0.0034]) tensor([2.6924e-06])
# 40 tensor([0.0008]) tensor([2.6924e-06])
# 50 tensor([0.0002]) tensor([2.6924e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.7081]) tensor([3.5180e-06])
# 20 tensor([0.0359]) tensor([3.5180e-06])
# 30 tensor([0.0053]) tensor([3.5180e-06])
# 40 tensor([0.0013]) tensor([3.5180e-06])
# 50 tensor([0.0004]) tensor([3.5180e-06])
# 60 tensor([0.0002]) tensor([3.5180e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.7850]) tensor([4.0223e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 20 tensor([0.0441]) tensor([4.0223e-06])
# 30 tensor([0.0068]) tensor([4.0223e-06])
# 40 tensor([0.0017]) tensor([4.0223e-06])
# 50 tensor([0.0005]) tensor([4.0223e-06])
# 60 tensor([0.0002]) tensor([4.0223e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.7695]) tensor([3.7654e-06])
# 20 tensor([0.0410]) tensor([3.7654e-06])
# 30 tensor([0.0063]) tensor([3.7654e-06])
# 40 tensor([0.0015]) tensor([3.7654e-06])
# 50 tensor([0.0005]) tensor([3.7654e-06])
# 60 tensor([0.0002]) tensor([3.7654e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.2861]) tensor([2.0652e-06])
# NAG did not manage to find precise enough solution
# 20 tensor([0.0142]) tensor([2.0652e-06])
# 30 tensor([0.0021]) tensor([2.0652e-06])
# 40 tensor([0.0005]) tensor([2.0652e-06])
# 50 tensor([0.0002]) tensor([2.0652e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.3221]) tensor([2.3978e-06])
# 20 tensor([0.0170]) tensor([2.3978e-06])
# 30 tensor([0.0025]) tensor([2.3978e-06])
# 40 tensor([0.0006]) tensor([2.3978e-06])
# 50 tensor([0.0002]) tensor([2.3978e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.2887]) tensor([2.0243e-06])
# 20 tensor([0.0143]) tensor([2.0243e-06])
# 30 tensor([0.0021]) tensor([2.0243e-06])
# 40 tensor([0.0005]) tensor([2.0243e-06])
# 50 tensor([0.0002]) tensor([2.0243e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.4494]) tensor([2.8073e-06])
# 20 tensor([0.0232]) tensor([2.8073e-06])
# 30 tensor([0.0034]) tensor([2.8073e-06])
# 40 tensor([0.0008]) tensor([2.8073e-06])
# 50 tensor([0.0003]) tensor([2.8073e-06])
# 60 tensor([0.0001]) tensor([2.8073e-06])
# Iteration complete
# 110 [16612.7, 1854.32128014538] [6871.8, 678.5689058599723]
# NAG did not manage to find precise enough solution
# 10 tensor([0.6458]) tensor([3.7756e-06])
# 20 tensor([0.0329]) tensor([3.7756e-06])
# 30 tensor([0.0048]) tensor([3.7756e-06])
# 40 tensor([0.0012]) tensor([3.7756e-06])
# 50 tensor([0.0004]) tensor([3.7756e-06])
# 60 tensor([0.0001]) tensor([3.7756e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.3414]) tensor([2.6831e-06])
# 20 tensor([0.0175]) tensor([2.6831e-06])
# 30 tensor([0.0025]) tensor([2.6831e-06])
# 40 tensor([0.0006]) tensor([2.6831e-06])
# 50 tensor([0.0002]) tensor([2.6831e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.7591]) tensor([4.2822e-06])
# 20 tensor([0.0404]) tensor([4.2822e-06])
# 30 tensor([0.0059]) tensor([4.2822e-06])
# 40 tensor([0.0014]) tensor([4.2822e-06])
# 50 tensor([0.0005]) tensor([4.2822e-06])
# 60 tensor([0.0002]) tensor([4.2822e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.8925]) tensor([4.8458e-06])
# 20 tensor([0.0501]) tensor([4.8458e-06])
# 30 tensor([0.0077]) tensor([4.8458e-06])
# 40 tensor([0.0019]) tensor([4.8458e-06])
# 50 tensor([0.0006]) tensor([4.8458e-06])
# 60 tensor([0.0002]) tensor([4.8458e-06])
# 70 tensor([0.0001]) tensor([4.8458e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.4790]) tensor([3.2043e-06])
# 20 tensor([0.0250]) tensor([3.2043e-06])
# 30 tensor([0.0037]) tensor([3.2043e-06])
# 40 tensor([0.0009]) tensor([3.2043e-06])
# 50 tensor([0.0003]) tensor([3.2043e-06])
# 60 tensor([0.0001]) tensor([3.2043e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.6799]) tensor([3.7577e-06])
# NAG did not manage to find precise enough solution
# 20 tensor([0.0349]) tensor([3.7577e-06])
# 30 tensor([0.0051]) tensor([3.7577e-06])
# 40 tensor([0.0012]) tensor([3.7577e-06])
# 50 tensor([0.0004]) tensor([3.7577e-06])
# 60 tensor([0.0001]) tensor([3.7577e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.4976]) tensor([3.3255e-06])
# 20 tensor([0.0263]) tensor([3.3255e-06])
# 30 tensor([0.0039]) tensor([3.3255e-06])
# 40 tensor([0.0009]) tensor([3.3255e-06])
# 50 tensor([0.0003]) tensor([3.3255e-06])
# 60 tensor([0.0001]) tensor([3.3255e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.3617]) tensor([2.8379e-06])
# NAG did not manage to find precise enough solution
# 20 tensor([0.0193]) tensor([2.8379e-06])
# 30 tensor([0.0028]) tensor([2.8379e-06])
# 40 tensor([0.0007]) tensor([2.8379e-06])
# 50 tensor([0.0002]) tensor([2.8379e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.8331]) tensor([4.5152e-06])
# 20 tensor([0.0457]) tensor([4.5152e-06])
# 30 tensor([0.0070]) tensor([4.5152e-06])
# 40 tensor([0.0017]) tensor([4.5152e-06])
# 50 tensor([0.0005]) tensor([4.5152e-06])
# 60 tensor([0.0002]) tensor([4.5152e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.9137]) tensor([4.6383e-06])
# 20 tensor([0.0471]) tensor([4.6383e-06])
# 30 tensor([0.0072]) tensor([4.6383e-06])
# 40 tensor([0.0018]) tensor([4.6383e-06])
# 50 tensor([0.0006]) tensor([4.6383e-06])
# 60 tensor([0.0002]) tensor([4.6383e-06])
# Iteration complete
# 120 [18994.3, 1785.6043262716407] [7408.5, 636.3016973103246]
# NAG did not manage to find precise enough solution
# 10 tensor([0.3523]) tensor([2.9935e-06])
# NAG did not manage to find precise enough solution
# 20 tensor([0.0182]) tensor([2.9935e-06])
# 30 tensor([0.0027]) tensor([2.9935e-06])
# 40 tensor([0.0006]) tensor([2.9935e-06])
# 50 tensor([0.0002]) tensor([2.9935e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([1.2483]) tensor([6.6299e-06])
# 20 tensor([0.0693]) tensor([6.6299e-06])
# 30 tensor([0.0106]) tensor([6.6299e-06])
# 40 tensor([0.0026]) tensor([6.6299e-06])
# 50 tensor([0.0008]) tensor([6.6299e-06])
# 60 tensor([0.0003]) tensor([6.6299e-06])
# 70 tensor([0.0001]) tensor([6.6299e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.7882]) tensor([4.7722e-06])
# 20 tensor([0.0400]) tensor([4.7722e-06])
# 30 tensor([0.0059]) tensor([4.7722e-06])
# 40 tensor([0.0014]) tensor([4.7722e-06])
# 50 tensor([0.0005]) tensor([4.7722e-06])
# 60 tensor([0.0002]) tensor([4.7722e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.6325]) tensor([4.5130e-06])
# 20 tensor([0.0345]) tensor([4.5130e-06])
# 30 tensor([0.0053]) tensor([4.5130e-06])
# 40 tensor([0.0013]) tensor([4.5130e-06])
# 50 tensor([0.0004]) tensor([4.5130e-06])
# 60 tensor([0.0002]) tensor([4.5130e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.5147]) tensor([3.8173e-06])
# 20 tensor([0.0267]) tensor([3.8173e-06])
# 30 tensor([0.0039]) tensor([3.8173e-06])
# 40 tensor([0.0009]) tensor([3.8173e-06])
# 50 tensor([0.0003]) tensor([3.8173e-06])
# 60 tensor([0.0001]) tensor([3.8173e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.7370]) tensor([5.1122e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 20 tensor([0.0429]) tensor([5.1122e-06])
# 30 tensor([0.0066]) tensor([5.1122e-06])
# 40 tensor([0.0016]) tensor([5.1122e-06])
# 50 tensor([0.0005]) tensor([5.1122e-06])
# 60 tensor([0.0002]) tensor([5.1122e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.4030]) tensor([3.3915e-06])
# 20 tensor([0.0216]) tensor([3.3915e-06])
# 30 tensor([0.0032]) tensor([3.3915e-06])
# 40 tensor([0.0008]) tensor([3.3915e-06])
# 50 tensor([0.0002]) tensor([3.3915e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.2628]) tensor([2.4654e-06])
# 20 tensor([0.0125]) tensor([2.4654e-06])
# 30 tensor([0.0018]) tensor([2.4654e-06])
# 40 tensor([0.0004]) tensor([2.4654e-06])
# 50 tensor([0.0001]) tensor([2.4654e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.3945]) tensor([3.3915e-06])
# 20 tensor([0.0208]) tensor([3.3915e-06])
# 30 tensor([0.0031]) tensor([3.3915e-06])
# 40 tensor([0.0007]) tensor([3.3915e-06])
# 50 tensor([0.0002]) tensor([3.3915e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.4014]) tensor([3.3596e-06])
# 20 tensor([0.0212]) tensor([3.3596e-06])
# 30 tensor([0.0031]) tensor([3.3596e-06])
# 40 tensor([0.0008]) tensor([3.3596e-06])
# 50 tensor([0.0002]) tensor([3.3596e-06])
# Iteration complete
# 130 [19500.8, 2628.376639677046] [7180.4, 863.0493844502759]
# NAG did not manage to find precise enough solution
# 10 tensor([0.4559]) tensor([4.0932e-06])
# 20 tensor([0.0245]) tensor([4.0932e-06])
# 30 tensor([0.0036]) tensor([4.0932e-06])
# 40 tensor([0.0009]) tensor([4.0932e-06])
# 50 tensor([0.0003]) tensor([4.0932e-06])
# 60 tensor([0.0001]) tensor([4.0932e-06])
# NAG did not manage to find precise enough solution
# 10 tensor([0.6598]) tensor([4.9690e-06])
# 20 tensor([0.0349]) tensor([4.9690e-06])
# 30 tensor([0.0053]) tensor([4.9690e-06])
# 40 tensor([0.0013]) tensor([4.9690e-06])
# 50 tensor([0.0004]) tensor([4.9690e-06])
# 60 tensor([0.0002]) tensor([4.9690e-06])
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# NAG did not manage to find precise enough solution
# 10 tensor([0.3825]) tensor([3.6377e-06])
# 20 tensor([0.0205]) tensor([3.6377e-06])
# 30 tensor([0.0030]) tensor([3.6377e-06])
# 40 tensor([0.0007]) tensor([3.6377e-06])
# 50 tensor([0.0002]) tensor([3.6377e-06])
# NAG did not manage to find precise enough solution
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-266-70e4d83a0f65> in <module>()
#      28         stop_cr = (f_opt, eps)
#      29
# ---> 30         nag_iters = fNAG(f, x_0, grad_f, stop_cr, L = L)
#      31         hf_iters, BDGM_iters = HyperFast(f, L_3, tau, stop_cr, axil_eps, axil_iter, max_iter)
#      32
#
# <ipython-input-258-658f534d95eb> in fNAG(f, x_0, gradient, stop_cr, L, max_iter)
#       6
#       7     while(len(iterations) <= max_iter):
# ----> 8         if(abs(f(x_0) - f_opt) <= eps):
#       9             break
#      10         k += 1
#
# <ipython-input-266-70e4d83a0f65> in <lambda>(x)
#      19         for i in range(0, m):
#      20             A[i] = torch.tensor(random(n, M = 1))
# ---> 21         f = lambda x: log_reg(x, A)
#      22         grad_f = lambda x: grad_logreg(x, A)
#      23         L = L_logreg(A)
#
# <ipython-input-255-24ccd5f5345c> in log_reg(x, A)
#       7     s = torch.zeros(1)
#       8     for i in range(A.shape[0]):
# ----> 9         s += torch.log(1 + torch.exp(torch.matmul(A[i], x)))
#      10     return s
#      11
#
# KeyboardInterrupt:

# %%
nag_oracle_compl = np.array(nag_oracle_compl)
hf_oracle_compl = np.array(hf_oracle_compl)

# %%
plt.errorbar(ns[:len(nag_oracle_compl)], nag_oracle_compl[:,0], yerr = nag_oracle_compl[:,1], label = 'NAG')
plt.scatter(ns[:len(nag_oracle_compl)], nag_oracle_compl[:,0])
plt.errorbar(ns[:len(hf_oracle_compl)], hf_oracle_compl[:,0], yerr = hf_oracle_compl[:,1], label = 'Hyperfast')
plt.scatter(ns[:len(hf_oracle_compl)], hf_oracle_compl[:,0])
plt.xlabel(r'$n$', size = 15)
plt.ylabel('calls to gradient', size = 15)
plt.legend()
plt.title(r'The number of calls to gradient $f$ and dimension of the problem $n$', size = 20)
plt.savefig('HF.pdf')
